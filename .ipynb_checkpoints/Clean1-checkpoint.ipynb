# %%
import pandas as pd

# %%
import numpy as np

# %%
data = pd.read_csv("test.csv")

# %%
df = data.copy()

# %%
st = data['summary'][0]

# %%
st
# Out:
# '--- {"editor":"simple"} --- **Data Origin:** Open data linked via [@makeovermonday](https://data.world/makeovermonday) **Who:** Dataset owned and managed by Makeover Monday **What:** Quarterly reports produced by Transport for London that provide analysis of incidents on the London bus network. **When:** 2018 **Auto-Sync:** Weekly **Cite:** London Bus Safety, Makeover Monday **_Source:_** [https://data.world/makeovermonday/2018w51](https://data.world/makeovermonday/2018w51)[Transport for London](https://tfl.gov.uk/corporate/publications-and-reports/bus-safety-data)[London Buses Safety Dashboard – Q2](https://tfl.gov.uk/cdn/static/cms/documents/q2-18-london-bus-safety-dashboard.pdf)'

# %%
lst = st.split("**")

# %%
lst
# Out:
# ['--- {"editor":"simple"} --- ',
#  'Data Origin:',
#  ' Open data linked via [@makeovermonday](https://data.world/makeovermonday) ',
#  'Who:',
#  ' Dataset owned and managed by Makeover Monday ',
#  'What:',
#  ' Quarterly reports produced by Transport for London that provide analysis of incidents on the London bus network. ',
#  'When:',
#  ' 2018 ',
#  'Auto-Sync:',
#  ' Weekly ',
#  'Cite:',
#  ' London Bus Safety, Makeover Monday ',
#  '_Source:_',
#  ' [https://data.world/makeovermonday/2018w51](https://data.world/makeovermonday/2018w51)[Transport for London](https://tfl.gov.uk/corporate/publications-and-reports/bus-safety-data)[London Buses Safety Dashboard – Q2](https://tfl.gov.uk/cdn/static/cms/documents/q2-18-london-bus-safety-dashboard.pdf)']

# %%
df['Data Origin'], df['Who'], df['What'], df['When'], df['Auto-Sync'], df['_Source_'] = [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan]

# %%
if(lst.index("Data Origin:")>0):
    print("Data Origin: " + lst[lst.index("Data Origin:")+1])
elif(lst.index("Who:")>0):
    print("Who: " + lst[lst.index("Who:")+1])
elif(lst.index("What:")>0):
    print("What: " + lst[lst.index("What:")+1])
elif(lst.index("When:")>0):
    print("When: " + lst[lst.index("When:")+1])
elif(lst.index("Auto-Sync:")>0):
    print("Auto-Sync: " + lst[lst.index("Auto-Sync:")+1])
elif(lst.index("_Source:_")>0):
    print("_Source:_ " + lst[lst.index("_Source:_")+1])
else:
    print("NaN")
# Out:
# Data Origin:  Open data linked via [@makeovermonday](https://data.world/makeovermonday)

# %%
lst[lst.index("Data Origin:")+1]
# Out:
# ' Open data linked via [@makeovermonday](https://data.world/makeovermonday) '

# %%
for index, row in df.iterrows(): 
    txt = str(row["summary"])
    ls = txt.split("**")
    if(lst.index("Data Origin:")>0):
        df["Data Origin"] = lst[lst.index("Data Origin:")+1]
    if(lst.index("Who:")>0):
        df["Who"] = lst[lst.index("Who:")+1]
    if(lst.index("What:")>0):
        df["What"] = lst[lst.index("What:")+1]
    if(lst.index("When:")>0):
        df["When"] = lst[lst.index("When:")+1]
    if(lst.index("Auto-Sync:")>0):
        df["Auto-Sync"] = lst[lst.index("Auto-Sync:")+1]
    if(lst.index("_Source:_")>0):
        df["_Source_"] = lst[lst.index("_Source:_")+1]

# %%
df
# Out:
#                 owner                                          datasetid  \
# 0              wp-ddw              2018w51-london-bus-safety-performance
# 1              wp-ddw                           business-glossary-source
# 2              wp-ddw                                 collections-source
# 3              wp-ddw                                    datasets-source
# 4              wp-ddw                                  ddw-catalogs-flat
# ..                ...                                                ...
# 312  wppdatacatalogue  novel-coronavirus-covid-19-cases-provided-by-j...
# 313  wppdatacatalogue                              open-catalog-products
# 314  wppdatacatalogue                                     wpp-bball-team
# 315  wppdatacatalogue                          wpp-data-catalog-datasets
# 316  wppdatacatalogue              yougov-international-covid-19-tracker
#
#                                                  name  \
# 0               2018w51-london-bus-safety-performance
# 1                            business-glossary-source
# 2                                  collections-source
# 3                                     datasets-source
# 4                                   ddw-catalogs-flat
# ..                                                ...
# 312  COVID-19 (2019-nCoV) Data Repository by JHU CSSE
# 313                              Open Product Catalog
# 314                 WPP Catalogue - Reference Dataset
# 315                       WPP Data Catalog - Datasets
# 316             YouGov International COVID-19 Tracker
#
#                                            description  \
# 0    Transport for London quarterly reports that pr...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 312  This is the data repository for the 2019 Novel...
# 313  To showcase the status of WPP Open Product Cat...
# 314  Description: Quick reference to what data is c...
# 315  A dataset that contains a list of names and UR...
# 316  YouGov's international COVID-19 tracker will b...
#
#                                                summary createdby_agentid  \
# 0    --- {"editor":"simple"} --- **Data Origin:** O...           willard
# 1                                                  NaN           willard
# 2                                                  NaN           willard
# 3                                                  NaN           willard
# 4                                                  NaN           willard
# ..                                                 ...               ...
# 312  --- {"editor":"simple"} --- **Data Origin:** J...            eclerf
# 313                                                NaN     jamesbirchall
# 314  --- {"editor":"simple"} --- **Summary:** Expla...            eclerf
# 315  --- {"editor":"simple"} --- This dataset conta...            eclerf
# 316  --- {"editor":"simple"} --- **Data Origin:** Y...            eclerf
#
#      createdby_client                  created                  updated  \
# 0    prod-user-client  2020-01-31T14:44:54.834   2020-04-24T19:13:52.67
# 1    prod-user-client  2020-03-09T22:37:29.621  2020-04-14T22:14:41.462
# 2    prod-user-client  2020-04-14T21:10:39.773  2020-04-14T21:11:52.783
# 3    prod-user-client  2020-04-14T20:50:43.539   2020-04-24T19:18:35.43
# 4    prod-user-client  2020-03-09T16:05:13.118  2020-07-31T16:47:17.423
# ..                ...                      ...                      ...
# 312  prod-user-client  2020-03-19T22:48:40.856  2020-08-05T22:21:40.602
# 313  prod-user-client  2020-08-04T10:01:11.043  2020-08-06T15:25:31.714
# 314  prod-user-client  2019-12-05T22:36:12.286  2020-08-06T15:28:33.545
# 315  prod-user-client  2020-07-23T19:33:24.778  2020-08-06T15:28:20.563
# 316  prod-user-client  2020-03-19T21:11:44.462  2020-08-06T15:20:22.672
#
#     visibility license                                               tags  \
# 0      PRIVATE     NaN  open data;transportation;transport for london;...
# 1      PRIVATE     NaN                                                NaN
# 2      PRIVATE     NaN                                                NaN
# 3      PRIVATE     NaN                                                NaN
# 4      PRIVATE     NaN                                                NaN
# ..         ...     ...                                                ...
# 312    PRIVATE   Other  covid 19;covid;coronavirus;virus;health;health...
# 313    PRIVATE     NaN                                                NaN
# 314    PRIVATE     NaN  topic;category;data source;department;team;own...
# 315    PRIVATE     NaN                                          reference
# 316    PRIVATE     NaN  covid 19;covid;coronavirus;virus;pandemic;heal...
#
#                                            Data Origin  \
# 0     Open data linked via [@makeovermonday](https:...
# 1     Open data linked via [@makeovermonday](https:...
# 2     Open data linked via [@makeovermonday](https:...
# 3     Open data linked via [@makeovermonday](https:...
# 4     Open data linked via [@makeovermonday](https:...
# ..                                                 ...
# 312   Open data linked via [@makeovermonday](https:...
# 313   Open data linked via [@makeovermonday](https:...
# 314   Open data linked via [@makeovermonday](https:...
# 315   Open data linked via [@makeovermonday](https:...
# 316   Open data linked via [@makeovermonday](https:...
#
#                                                 Who  \
# 0     Dataset owned and managed by Makeover Monday
# 1     Dataset owned and managed by Makeover Monday
# 2     Dataset owned and managed by Makeover Monday
# 3     Dataset owned and managed by Makeover Monday
# 4     Dataset owned and managed by Makeover Monday
# ..                                              ...
# 312   Dataset owned and managed by Makeover Monday
# 313   Dataset owned and managed by Makeover Monday
# 314   Dataset owned and managed by Makeover Monday
# 315   Dataset owned and managed by Makeover Monday
# 316   Dataset owned and managed by Makeover Monday
#
#                                                   What    When Auto-Sync  \
# 0     Quarterly reports produced by Transport for L...   2018    Weekly
# 1     Quarterly reports produced by Transport for L...   2018    Weekly
# 2     Quarterly reports produced by Transport for L...   2018    Weekly
# 3     Quarterly reports produced by Transport for L...   2018    Weekly
# 4     Quarterly reports produced by Transport for L...   2018    Weekly
# ..                                                 ...     ...       ...
# 312   Quarterly reports produced by Transport for L...   2018    Weekly
# 313   Quarterly reports produced by Transport for L...   2018    Weekly
# 314   Quarterly reports produced by Transport for L...   2018    Weekly
# 315   Quarterly reports produced by Transport for L...   2018    Weekly
# 316   Quarterly reports produced by Transport for L...   2018    Weekly
#
#                                               _Source_
# 0     [https://data.world/makeovermonday/2018w51](h...
# 1     [https://data.world/makeovermonday/2018w51](h...
# 2     [https://data.world/makeovermonday/2018w51](h...
# 3     [https://data.world/makeovermonday/2018w51](h...
# 4     [https://data.world/makeovermonday/2018w51](h...
# ..                                                 ...
# 312   [https://data.world/makeovermonday/2018w51](h...
# 313   [https://data.world/makeovermonday/2018w51](h...
# 314   [https://data.world/makeovermonday/2018w51](h...
# 315   [https://data.world/makeovermonday/2018w51](h...
# 316   [https://data.world/makeovermonday/2018w51](h...
#
# [317 rows x 18 columns]

# %%
txt1 = "**Data Origin:** Open data linked via [@makeovermonday](/makeovermonday) **Who:** Dataset owned and managed by Makeover Monday **What:** **About this Dataset** * DATA SOURCE: [Transport for London](http://cycling.data.tfl.gov.uk/) * DESIGNER: [Sophie Sparks](https://twitter.com/sophie_sparkes) *"

# %%
txt1.split("**")
# Out:
# ['',
#  'Data Origin:',
#  ' Open data linked via [@makeovermonday](/makeovermonday) ',
#  'Who:',
#  ' Dataset owned and managed by Makeover Monday ',
#  'What:',
#  ' ',
#  'About this Dataset',
#  ' * DATA SOURCE: [Transport for London](http://cycling.data.tfl.gov.uk/) * DESIGNER: [Sophie Sparks](https://twitter.com/sophie_sparkes) *']
