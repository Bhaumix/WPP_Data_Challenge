# %%
from google.cloud import language_v1
from google.cloud.language_v1 import enums


def sample_analyze_entities(text_content):
    """
    Analyzing Entities in a String

    Args:
      text_content The text content to analyze
    """

    client = language_v1.LanguageServiceClient.from_service_account_json("services.json")

    # text_content = 'California is a state.'

    # Available types: PLAIN_TEXT, HTML
    type_ = enums.Document.Type.PLAIN_TEXT

    # Optional. If not specified, the language is automatically detected.
    # For list of supported languages:
    # https://cloud.google.com/natural-language/docs/languages
    language = "en"
    document = {"content": text_content, "type": type_, "language": language}

    # Available values: NONE, UTF8, UTF16, UTF32
    encoding_type = enums.EncodingType.UTF8

    response = client.analyze_entities(document, encoding_type=encoding_type)

    # Loop through entitites returned from the API
    for entity in response.entities:
        print(u"Representative name for the entity: {}".format(entity.name))

        # Get entity type, e.g. PERSON, LOCATION, ADDRESS, NUMBER, et al
        print(u"Entity type: {}".format(enums.Entity.Type(entity.type).name))

        # Get the salience score associated with the entity in the [0, 1.0] range
        print(u"Salience score: {}".format(entity.salience))

        # Loop over the metadata associated with entity. For many known entities,
        # the metadata is a Wikipedia URL (wikipedia_url) and Knowledge Graph MID (mid).
        # Some entity types may have additional metadata, e.g. ADDRESS entities
        # may have metadata for the address street_name, postal_code, et al.
        for metadata_name, metadata_value in entity.metadata.items():
            print(u"{}: {}".format(metadata_name, metadata_value))

        # Loop over the mentions of this entity in the input document.
        # The API currently supports proper noun mentions.
        for mention in entity.mentions:
            print(u"Mention text: {}".format(mention.text.content))

            # Get the mention type, e.g. PROPER for proper noun
            print(
                u"Mention type: {}".format(enums.EntityMention.Type(mention.type).name)
            )

    # Get the language of the text, which will be the same as
    # the language specified in the request or, if not specified,
    # the automatically-detected language.
    print(u"Language of the text: {}".format(response.language))

# %%
Text = "The 2020 edition of this report is the third year that BrandZ has ranked the Top 100 US brands The headline is that they grew 5 over 2019 with a new number one Amazon that is worth more than a third of a trillion dollars the most ever for any brand in our rankings US brands are also pound for pound easily the most valuable in the world In aggregate they are nearly four times as valuable as the second most valuable ranking China s and they are also worth more than any other country s when adjusted for GDP Top US brands come from an enormously wide range of categories which makes them ideal case studies for nearly any kind of brand looking to distinguish itself in the marketplace To single out a few examples for special recognition Chipotle this year has shown how a challenged brand can effectively respond to a crisis of confidence Walmart and Target have amply demonstrated that you can compete with Amazon so long as you have a thoughtful strategy And smaller social networks Instagram LinkedIn Pinterest and Twitter proved that a high level of Meaningful Difference can lead to explosive growth in brand valueThe BrandZ Top 100 Most Valuable USA Brands Bra"

# %%
sample_analyze_entities(Text)
# Out:
# Representative name for the entity: BrandZ
# Entity type: ORGANIZATION
# Salience score: 0.329344242811203
# mid: /g/11c6yhttv4
# Mention text: BrandZ
# Mention type: PROPER
# Mention text: BrandZ
# Mention type: PROPER
# Representative name for the entity: Amazon
# Entity type: ORGANIZATION
# Salience score: 0.14518795907497406
# wikipedia_url: https://en.wikipedia.org/wiki/Amazon_(company)
# mid: /m/0mgkg
# Mention text: Amazon
# Mention type: PROPER
# Mention text: Amazon
# Mention type: PROPER
# Representative name for the entity: brands
# Entity type: ORGANIZATION
# Salience score: 0.05363289266824722
# Mention text: brands
# Mention type: COMMON
# Representative name for the entity: brand
# Entity type: OTHER
# Salience score: 0.03811746463179588
# Mention text: brand
# Mention type: COMMON
# Representative name for the entity: edition
# Entity type: EVENT
# Salience score: 0.037883955985307693
# Mention text: edition
# Mention type: COMMON
# Representative name for the entity: headline
# Entity type: OTHER
# Salience score: 0.037883955985307693
# Mention text: headline
# Mention type: COMMON
# Representative name for the entity: categories
# Entity type: OTHER
# Salience score: 0.032992467284202576
# Mention text: categories
# Mention type: COMMON
# Representative name for the entity: report
# Entity type: WORK_OF_ART
# Salience score: 0.03166050463914871
# Mention text: report
# Mention type: COMMON
# Representative name for the entity: US
# Entity type: LOCATION
# Salience score: 0.02491036430001259
# wikipedia_url: https://en.wikipedia.org/wiki/United_States
# mid: /m/09c7w0
# Mention text: US
# Mention type: PROPER
# Mention text: US
# Mention type: PROPER
# Mention text: US
# Mention type: PROPER
# Mention text: USA
# Mention type: PROPER
# Representative name for the entity: brand
# Entity type: OTHER
# Salience score: 0.020844483748078346
# Mention text: brand
# Mention type: COMMON
# Representative name for the entity: brands
# Entity type: ORGANIZATION
# Salience score: 0.01430672686547041
# Mention text: brands
# Mention type: COMMON
# Representative name for the entity: brands
# Entity type: OTHER
# Salience score: 0.014133629389107227
# Mention text: brands
# Mention type: COMMON
# Representative name for the entity: third
# Entity type: OTHER
# Salience score: 0.013830391690135002
# Mention text: third
# Mention type: COMMON
# Representative name for the entity: number one
# Entity type: PERSON
# Salience score: 0.01216310914605856
# Mention text: number one
# Mention type: COMMON
# Representative name for the entity: country
# Entity type: LOCATION
# Salience score: 0.010898265987634659
# Mention text: country
# Mention type: COMMON
# Representative name for the entity: GDP Top
# Entity type: OTHER
# Salience score: 0.010381572879850864
# Mention text: GDP Top
# Mention type: COMMON
# Representative name for the entity: valuable
# Entity type: OTHER
# Salience score: 0.010255557484924793
# Mention text: valuable
# Mention type: COMMON
# Representative name for the entity: ranking
# Entity type: OTHER
# Salience score: 0.009474977850914001
# Mention text: ranking
# Mention type: COMMON
# Representative name for the entity: rankings
# Entity type: OTHER
# Salience score: 0.009359880350530148
# Mention text: rankings
# Mention type: COMMON
# Representative name for the entity: pound
# Entity type: OTHER
# Salience score: 0.009359880350530148
# Mention text: pound
# Mention type: COMMON
# Representative name for the entity: world
# Entity type: LOCATION
# Salience score: 0.008227807469666004
# Mention text: world
# Mention type: COMMON
# Representative name for the entity: aggregate
# Entity type: OTHER
# Salience score: 0.008227807469666004
# Mention text: aggregate
# Mention type: COMMON
# Representative name for the entity: times
# Entity type: OTHER
# Salience score: 0.008028916083276272
# Mention text: times
# Mention type: COMMON
# Representative name for the entity: range
# Entity type: OTHER
# Salience score: 0.0076453471556305885
# Mention text: range
# Mention type: COMMON
# Representative name for the entity: case studies
# Entity type: OTHER
# Salience score: 0.0076453471556305885
# Mention text: case studies
# Mention type: COMMON
# Representative name for the entity: kind
# Entity type: OTHER
# Salience score: 0.0076453471556305885
# Mention text: kind
# Mention type: COMMON
# Representative name for the entity: marketplace
# Entity type: OTHER
# Salience score: 0.0076453471556305885
# Mention text: marketplace
# Mention type: COMMON
# Representative name for the entity: brand
# Entity type: OTHER
# Salience score: 0.0069595095701515675
# Mention text: brand
# Mention type: COMMON
# Representative name for the entity: Brands
# Entity type: ORGANIZATION
# Salience score: 0.0069595095701515675
# Mention text: Brands
# Mention type: COMMON
# Representative name for the entity: social networks
# Entity type: OTHER
# Salience score: 0.005768121685832739
# Mention text: social networks
# Mention type: COMMON
# Representative name for the entity: strategy
# Entity type: OTHER
# Salience score: 0.0056978389620780945
# Mention text: strategy
# Mention type: COMMON
# Representative name for the entity: Chipotle
# Entity type: OTHER
# Salience score: 0.005682735238224268
# Mention text: Chipotle
# Mention type: PROPER
# Mention text: recognition
# Mention type: COMMON
# Representative name for the entity: China
# Entity type: LOCATION
# Salience score: 0.004933991003781557
# mid: /m/0d05w3
# wikipedia_url: https://en.wikipedia.org/wiki/China
# Mention text: China
# Mention type: PROPER
# Representative name for the entity: level
# Entity type: OTHER
# Salience score: 0.0043501537293195724
# Mention text: level
# Mention type: COMMON
# Representative name for the entity: brand
# Entity type: ORGANIZATION
# Salience score: 0.004057351965457201
# Mention text: brand
# Mention type: COMMON
# Representative name for the entity: growth
# Entity type: OTHER
# Salience score: 0.004041272681206465
# Mention text: growth
# Mention type: COMMON
# Representative name for the entity: Difference
# Entity type: OTHER
# Salience score: 0.004041272681206465
# Mention text: Difference
# Mention type: COMMON
# Representative name for the entity: Target
# Entity type: ORGANIZATION
# Salience score: 0.003413951024413109
# wikipedia_url: https://en.wikipedia.org/wiki/Target_Corporation
# mid: /m/01b39j
# Mention text: Target
# Mention type: PROPER
# Representative name for the entity: Instagram LinkedIn Pinterest
# Entity type: ORGANIZATION
# Salience score: 0.003413951024413109
# Mention text: Instagram LinkedIn Pinterest
# Mention type: PROPER
# Representative name for the entity: valueThe
# Entity type: OTHER
# Salience score: 0.002721219090744853
# Mention text: valueThe
# Mention type: PROPER
# Representative name for the entity: crisis
# Entity type: EVENT
# Salience score: 0.0025338137056678534
# Mention text: crisis
# Mention type: COMMON
# Representative name for the entity: confidence
# Entity type: OTHER
# Salience score: 0.0025338137056678534
# Mention text: confidence
# Mention type: COMMON
# Representative name for the entity: examples
# Entity type: OTHER
# Salience score: 0.0025338137056678534
# Mention text: examples
# Mention type: COMMON
# Representative name for the entity: Twitter
# Entity type: OTHER
# Salience score: 0.002390485256910324
# wikipedia_url: https://en.wikipedia.org/wiki/Twitter
# mid: /m/0289n8t
# Mention text: Twitter
# Mention type: PROPER
# Representative name for the entity: Bra
# Entity type: LOCATION
# Salience score: 0.002390485256910324
# wikipedia_url: https://en.wikipedia.org/wiki/Bra
# mid: /m/01gmv2
# Mention text: Bra
# Mention type: PROPER
# Representative name for the entity: Walmart
# Entity type: ORGANIZATION
# Salience score: 0.0014980288688093424
# wikipedia_url: https://en.wikipedia.org/wiki/Walmart
# mid: /m/0841v
# Mention text: Walmart
# Mention type: PROPER
# Representative name for the entity: 2020
# Entity type: DATE
# Salience score: 0.0
# year: 2020
# Mention text: 2020
# Mention type: TYPE_UNKNOWN
# Representative name for the entity: 2020
# Entity type: NUMBER
# Salience score: 0.0
# value: 2020
# Mention text: 2020
# Mention type: TYPE_UNKNOWN
# Representative name for the entity: 2019
# Entity type: NUMBER
# Salience score: 0.0
# value: 2019
# Mention text: 2019
# Mention type: TYPE_UNKNOWN
# Representative name for the entity: 100
# Entity type: NUMBER
# Salience score: 0.0
# value: 100
# Mention text: 100
# Mention type: TYPE_UNKNOWN
# Representative name for the entity: one
# Entity type: NUMBER
# Salience score: 0.0
# value: 1
# Mention text: one
# Mention type: TYPE_UNKNOWN
# Representative name for the entity: four
# Entity type: NUMBER
# Salience score: 0.0
# value: 4
# Mention text: four
# Mention type: TYPE_UNKNOWN
# Representative name for the entity: 100
# Entity type: NUMBER
# Salience score: 0.0
# value: 100
# Mention text: 100
# Mention type: TYPE_UNKNOWN
# Representative name for the entity: 5
# Entity type: NUMBER
# Salience score: 0.0
# value: 5
# Mention text: 5
# Mention type: TYPE_UNKNOWN
# Language of the text: en
