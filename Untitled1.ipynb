# %%
from IPython.display import clear_output
# !pip install pandas tqdm requests httplib2 google-cloud-language
clear_output()
print('All Installed.')
# Out:
# All Installed.

# %%
import sys
import httplib2
import pandas as pd
import logging
import time
from tqdm import tqdm
import warnings
import datetime as dt
import os
import string
from datetime import timedelta, date
from urllib.error import HTTPError
from IPython.display import clear_output
import requests
import json

from google.cloud import language
from google.oauth2 import service_account
from google.cloud.language import enums
from google.cloud.language import types

client = language.LanguageServiceClient.from_service_account_json('services.json')

# %%
def load_text_from_url(url, **data):
    
    '''
    Loads html from a URL
    Parameters:
        * url: url of page to load (str)
        * timeout: request timeout in seconds (int) default: 20
    Returns:
    HTML (str)
    '''
    
    timeout = data.get('timeout', 20)
    
    results = []
    
    try:
        
        print("Extracting text from: {}".format(url))
        response = requests.get(url, timeout=timeout)

        text = response.text
        status = response.status_code

        if status == 200 and len(text) > 0:
            file1 = open("myfile.txt","w")
            file1.write(text)
            file1.close()
            print("File generated")
            return text
            
        return None
        

    except Exception as e:
        print('Problem with url: {0}.'.format(url))
        return None

# %%
def pull_googlenlp(client, url, invalid_types = ['OTHER'], **data):
    
    '''
    Loads HTML from a URL and passes to the Google NLP API
    Parameters:
        * client: Authenticated Language Service Client.
        * url: url of page to load (str)
        * invalid_types: entitity types to ignore (eg. CONSUMER_GOOD, NUMBER) (list) default: OTHER
        * timeout: request timeout in seconds (int) default: 20
    Returns:
    Dictionary of sentiment(list), entities(list), categories(list) (dict)
    '''    

    html = load_text_from_url(url, **data)
    
    if not html:
        return None
    
    document = types.Document(
        content=html,
        type=language.enums.Document.Type.HTML )

    features = {'extract_syntax': True,
                'extract_entities': True,
                'extract_document_sentiment': True,
                'extract_entity_sentiment': True,
                'classify_text': False
                }
    
    response = client.annotate_text(document=document, features=features)
    sentiment = response.document_sentiment
    entities = response.entities
    
    response = client.classify_text(document)
    categories = response.categories
        
    def get_type(type):
        return client.enums.Entity.Type(entity.type).name
    
    result = {}
    
    result['sentiment'] = []    
    result['entities'] = []
    result['categories'] = []

    if sentiment:
        result['sentiment'] = [{ 'magnitude': sentiment.magnitude, 'score':sentiment.score }]
        
    for entity in entities:
        if get_type(entity.type) not in invalid_types:
            result['entities'].append({'name': entity.name, 'type': get_type(entity.type), 'salience': entity.salience, 'wikipedia_url': entity.metadata.get('wikipedia_url', '-')  })
            
    for category in categories:
        result['categories'].append({'name':category.name, 'confidence': category.confidence})
        
        
    return result

# %%
url = "https://opensource.com/article/19/6/how-ssh-running-container"
pull_googlenlp(client,url)
# Out:
# Extracting text from: https://opensource.com/article/19/6/how-ssh-running-container
# {'sentiment': [{'magnitude': 79.80000305175781, 'score': 0.0}],
#  'entities': [{'name': 'SSH',
#    'type': 'CONSUMER_GOOD',
#    'salience': 0.0326605923473835,
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Secure_Shell'},
#   {'name': 'Seth Kenlon',
#    'type': 'PERSON',
#    'salience': 0.025843223556876183,
#    'wikipedia_url': '-'},
#   {'name': 'Linux',
#    'type': 'CONSUMER_GOOD',
#    'salience': 0.02205348014831543,
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Linux'},
#   {'name': 'comments',
#    'type': 'WORK_OF_ART',
#    'salience': 0.01498269010335207,
#    'wikipedia_url': '-'},
#   {'name': 'Python',
#    'type': 'ORGANIZATION',
#    'salience': 0.007452790625393391,
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Python_(programming_language)'},
#   {'name': 'organization',
#    'type': 'ORGANIZATION',
#    'salience': 0.0066571542993187904,
#    'wikipedia_url': '-'},
#   {'name': 'open source tools',
#    'type': 'CONSUMER_GOOD',
#    'salience': 0.006460968870669603,
#    'wikipedia_url': '-'},
#   {'name': 'Red Hat',
#    'type': 'ORGANIZATION',
#    'salience': 0.004840615205466747,
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Red_Hat'},
#   {'name': 'Open Source Yearbook',
#    'type': 'WORK_OF_ART',
#    'salience': 0.0040302579291164875,
#    'wikipedia_url': '-'},
#   {'name': 'hiring guide',
#    'type': 'WORK_OF_ART',
#    'salience': 0.00371843995526433,
#    'wikipedia_url': '-'},
#   {'name': 'collaboration tools',
#    'type': 'CONSUMER_GOOD',
#    'salience': 0.0037155684549361467,
#    'wikipedia_url': '-'},
#   {'name': 'desktop tools',
#    'type': 'CONSUMER_GOOD',
#    'salience': 0.0037147803232073784,
#    'wikipedia_url': '-'},
#   {'name': 'Organizations',
#    'type': 'ORGANIZATION',
#    'salience': 0.0036466987803578377,
#    'wikipedia_url': '-'},
#   {'name': 'Docker',
#    'type': 'ORGANIZATION',
#    'salience': 0.003554106689989567,
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Docker_(software)'},
#   {'name': 'Articles',
#    'type': 'WORK_OF_ART',
#    'salience': 0.0028598031494766474,
#    'wikipedia_url': '-'},
#   {'name': 'Software',
#    'type': 'CONSUMER_GOOD',
#    'salience': 0.002798736095428467,
#    'wikipedia_url': '-'},
#   {'name': 'Open Organization',
#    'type': 'ORGANIZATION',
#    'salience': 0.0027750288136303425,
#    'wikipedia_url': '-'},
#   {'name': 'Containers',
#    'type': 'PERSON',
#    'salience': 0.0026245317421853542,
#    'wikipedia_url': '-'},
#   {'name': 'Government',
#    'type': 'ORGANIZATION',
#    'salience': 0.002596538048237562,
#    'wikipedia_url': '-'},
#   {'name': 'Python template libraries',
#    'type': 'LOCATION',
#    'salience': 0.0025538462214171886,
#    'wikipedia_url': '-'},
#   {'name': 'Photos',
#    'type': 'WORK_OF_ART',
#    'salience': 0.0025476040318608284,
#    'wikipedia_url': '-'},
#   {'name': 'libraries',
#    'type': 'LOCATION',
#    'salience': 0.0025315359234809875,
#    'wikipedia_url': '-'},
#   {'name': 'Introduction',
#    'type': 'EVENT',
#    'salience': 0.002530632773414254,
#    'wikipedia_url': '-'},
#   {'name': 'Python GUI frameworks',
#    'type': 'WORK_OF_ART',
#    'salience': 0.002244208939373493,
#    'wikipedia_url': '-'},
#   {'name': 'Publisher',
#    'type': 'ORGANIZATION',
#    'salience': 0.0022367099300026894,
#    'wikipedia_url': '-'},
#   {'name': 'Special Edition',
#    'type': 'WORK_OF_ART',
#    'salience': 0.0022240260150283575,
#    'wikipedia_url': '-'},
#   {'name': 'Discourse software',
#    'type': 'CONSUMER_GOOD',
#    'salience': 0.0021539274603128433,
#    'wikipedia_url': '-'},
#   {'name': 'container app',
#    'type': 'CONSUMER_GOOD',
#    'salience': 0.002140953904017806,
#    'wikipedia_url': '-'},
#   {'name': 'container app',
#    'type': 'CONSUMER_GOOD',
#    'salience': 0.0021397187374532223,
#    'wikipedia_url': '-'},
#   {'name': 'Arduino',
#    'type': 'CONSUMER_GOOD',
#    'salience': 0.0020038520451635122,
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Arduino'},
#   {'name': 'container',
#    'type': 'CONSUMER_GOOD',
#    'salience': 0.001899928436614573,
#    'wikipedia_url': '-'},
#   {'name': 'container',
#    'type': 'CONSUMER_GOOD',
#    'salience': 0.0017690376844257116,
#    'wikipedia_url': '-'},
#   {'name': 'Sysadmins',
#    'type': 'PERSON',
#    'salience': 0.0017600320279598236,
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/System_administrator'},
#   {'name': 'Building container images',
#    'type': 'WORK_OF_ART',
#    'salience': 0.0017051157774403691,
#    'wikipedia_url': '-'},
#   {'name': 'organization',
#    'type': 'ORGANIZATION',
#    'salience': 0.0016299685230478644,
#    'wikipedia_url': '-'},
#   {'name': 'organization',
#    'type': 'ORGANIZATION',
#    'salience': 0.0016244539292529225,
#    'wikipedia_url': '-'},
#   {'name': 'Microservices',
#    'type': 'ORGANIZATION',
#    'salience': 0.0015110832173377275,
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Microservices'},
#   {'name': 'AutoCAD',
#    'type': 'CONSUMER_GOOD',
#    'salience': 0.0015070203226059675,
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/AutoCAD'},
#   {'name': 'Photoshop',
#    'type': 'CONSUMER_GOOD',
#    'salience': 0.0015051329974085093,
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Adobe_Photoshop'},
#   {'name': 'IRC',
#    'type': 'ORGANIZATION',
#    'salience': 0.0014997371472418308,
#    'wikipedia_url': '-'},
#   {'name': 'style guide',
#    'type': 'WORK_OF_ART',
#    'salience': 0.0014032557373866439,
#    'wikipedia_url': '-'},
#   {'name': 'Guide',
#    'type': 'WORK_OF_ART',
#    'salience': 0.0014022166142240167,
#    'wikipedia_url': '-'},
#   {'name': 'Guide',
#    'type': 'WORK_OF_ART',
#    'salience': 0.0014020910020917654,
#    'wikipedia_url': '-'},
#   {'name': 'Discussion Guides',
#    'type': 'WORK_OF_ART',
#    'salience': 0.0014012372121214867,
#    'wikipedia_url': '-'},
#   {'name': 'Discussion Guides',
#    'type': 'WORK_OF_ART',
#    'salience': 0.0013965818798169494,
#    'wikipedia_url': '-'},
#   {'name': 'Organizations',
#    'type': 'ORGANIZATION',
#    'salience': 0.0013514426536858082,
#    'wikipedia_url': '-'},
#   {'name': 'Google',
#    'type': 'ORGANIZATION',
#    'salience': 0.0013221867848187685,
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Google'},
#   {'name': 'Skype',
#    'type': 'ORGANIZATION',
#    'salience': 0.0013214054051786661,
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Skype'},
#   {'name': 'Trello',
#    'type': 'PERSON',
#    'salience': 0.0013209048192948103,
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Trello'},
#   {'name': 'AWK',
#    'type': 'ORGANIZATION',
#    'salience': 0.001319717732258141,
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/AWK'},
#   {'name': 'Emacs',
#    'type': 'CONSUMER_GOOD',
#    'salience': 0.0013190454337745905,
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Emacs'},
#   {'name': 'FreeDOS',
#    'type': 'CONSUMER_GOOD',
#    'salience': 0.0013186123687773943,
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/FreeDOS'},
#   {'name': 'Inkscape',
#    'type': 'CONSUMER_GOOD',
#    'salience': 0.0013173792976886034,
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Inkscape'},
#   {'name': 'DevSecOps',
#    'type': 'ORGANIZATION',
#    'salience': 0.00131322187371552,
#    'wikipedia_url': '-'},
#   {'name': 'Image',
#    'type': 'WORK_OF_ART',
#    'salience': 0.0011851476738229394,
#    'wikipedia_url': '-'},
#   {'name': 'Newsletter',
#    'type': 'WORK_OF_ART',
#    'salience': 0.0010449138935655355,
#    'wikipedia_url': '-'},
#   {'name': 'ambassadors',
#    'type': 'PERSON',
#    'salience': 0.0010447389213368297,
#    'wikipedia_url': '-'},
#   {'name': 'Articles',
#    'type': 'WORK_OF_ART',
#    'salience': 0.0010441445047035813,
#    'wikipedia_url': '-'},
#   {'name': 'Newsletter',
#    'type': 'WORK_OF_ART',
#    'salience': 0.001041462761349976,
#    'wikipedia_url': '-'},
#   {'name': 'oc',
#    'type': 'PERSON',
#    'salience': 0.0010226803133264184,
#    'wikipedia_url': '-'},
#   {'name': 'team',
#    'type': 'ORGANIZATION',
#    'salience': 0.0009549860842525959,
#    'wikipedia_url': '-'},
#   {'name': 'Book series',
#    'type': 'WORK_OF_ART',
#    'salience': 0.0009539793245494366,
#    'wikipedia_url': '-'},
#   {'name': 'Government',
#    'type': 'ORGANIZATION',
#    'salience': 0.0009519719169475138,
#    'wikipedia_url': '-'},
#   {'name': 'Book series',
#    'type': 'WORK_OF_ART',
#    'salience': 0.0009501981548964977,
#    'wikipedia_url': '-'},
#   {'name': 'oc',
#    'type': 'PERSON',
#    'salience': 0.0009475453407503664,
#    'wikipedia_url': '-'},
#   {'name': 'toolchain',
#    'type': 'CONSUMER_GOOD',
#    'salience': 0.0009278140496462584,
#    'wikipedia_url': '-'},
#   {'name': 'stack',
#    'type': 'PERSON',
#    'salience': 0.0009084399789571762,
#    'wikipedia_url': '-'},
#   {'name': 'Leaders',
#    'type': 'PERSON',
#    'salience': 0.0008376846089959145,
#    'wikipedia_url': '-'},
#   {'name': 'Educators',
#    'type': 'PERSON',
#    'salience': 0.0008375340257771313,
#    'wikipedia_url': '-'},
#   {'name': 'NIC',
#    'type': 'CONSUMER_GOOD',
#    'salience': 0.0008334122248925269,
#    'wikipedia_url': '-'},
#   {'name': 'Field Guide',
#    'type': 'WORK_OF_ART',
#    'salience': 0.0008286146330647171,
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Field_guide'},
#   {'name': 'exec example',
#    'type': 'PERSON',
#    'salience': 0.0008114388911053538,
#    'wikipedia_url': '-'},
#   {'name': 'terminal',
#    'type': 'LOCATION',
#    'salience': 0.0007404747884720564,
#    'wikipedia_url': '-'},
#   {'name': 'container app',
#    'type': 'CONSUMER_GOOD',
#    'salience': 0.0007063859957270324,
#    'wikipedia_url': '-'},
#   {'name': 'tool',
#    'type': 'CONSUMER_GOOD',
#    'salience': 0.0006548531819134951,
#    'wikipedia_url': '-'},
#   {'name': 'panel',
#    'type': 'ORGANIZATION',
#    'salience': 0.0006466213962994516,
#    'wikipedia_url': '-'},
#   {'name': 'world',
#    'type': 'LOCATION',
#    'salience': 0.0006396877579391003,
#    'wikipedia_url': '-'},
#   {'name': 'state',
#    'type': 'LOCATION',
#    'salience': 0.0006396134267561138,
#    'wikipedia_url': '-'},
#   {'name': 'introduction',
#    'type': 'EVENT',
#    'salience': 0.0006393230869434774,
#    'wikipedia_url': '-'},
#   {'name': 'machines',
#    'type': 'CONSUMER_GOOD',
#    'salience': 0.0006336410297080874,
#    'wikipedia_url': '-'},
#   {'name': 'LXC',
#    'type': 'CONSUMER_GOOD',
#    'salience': 0.0006291044992394745,
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/LXC'},
#   {'name': 'running container',
#    'type': 'CONSUMER_GOOD',
#    'salience': 0.0006268206052482128,
#    'wikipedia_url': '-'},
#   {'name': 'location',
#    'type': 'LOCATION',
#    'salience': 0.0005681597976945341,
#    'wikipedia_url': '-'},
#   {'name': 'IT Culture Change',
#    'type': 'EVENT',
#    'salience': 0.000563445093575865,
#    'wikipedia_url': '-'},
#   {'name': 'web console',
#    'type': 'CONSUMER_GOOD',
#    'salience': 0.0005073102656751871,
#    'wikipedia_url': '-'},
#   {'name': 'forum',
#    'type': 'EVENT',
#    'salience': 0.0004934645257890224,
#    'wikipedia_url': '-'},
#   {'name': 'author',
#    'type': 'PERSON',
#    'salience': 0.0004885521484538913,
#    'wikipedia_url': '-'},
#   {'name': 'Terminal',
#    'type': 'EVENT',
#    'salience': 0.00047693439410068095,
#    'wikipedia_url': '-'},
#   {'name': 'docker exec',
#    'type': 'PERSON',
#    'salience': 0.00042620988097041845,
#    'wikipedia_url': '-'},
#   {'name': 'COMMAND',
#    'type': 'ORGANIZATION',
#    'salience': 0.00040407024789601564,
#    'wikipedia_url': '-'},
#   {'name': 'free culture advocate',
#    'type': 'PERSON',
#    'salience': 0.0003912885149475187,
#    'wikipedia_url': '-'},
#   {'name': 'film',
#    'type': 'WORK_OF_ART',
#    'salience': 0.00039127274067141116,
#    'wikipedia_url': '-'},
#   {'name': 'Jenkins',
#    'type': 'PERSON',
#    'salience': 0.00038215905078686774,
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Jenkins_(software)'},
#   {'name': 'Kubernetes Operators',
#    'type': 'ORGANIZATION',
#    'salience': 0.0003776449884753674,
#    'wikipedia_url': '-'},
#   {'name': 'newsletter',
#    'type': 'WORK_OF_ART',
#    'salience': 0.00034127169055864215,
#    'wikipedia_url': '-'},
#   {'name': 'author',
#    'type': 'PERSON',
#    'salience': 0.00034108172985725105,
#    'wikipedia_url': '-'},
#   {'name': 'author',
#    'type': 'PERSON',
#    'salience': 0.00034108172985725105,
#    'wikipedia_url': '-'},
#   {'name': 'bin/',
#    'type': 'PERSON',
#    'salience': 0.0003376425593160093,
#    'wikipedia_url': '-'},
#   {'name': 'OCI',
#    'type': 'ORGANIZATION',
#    'salience': 0.00033192557748407125,
#    'wikipedia_url': '-'},
#   {'name': 'name example-pod',
#    'type': 'CONSUMER_GOOD',
#    'salience': 0.00031652936013415456,
#    'wikipedia_url': '-'},
#   {'name': 'post',
#    'type': 'WORK_OF_ART',
#    'salience': 0.00031144145759753883,
#    'wikipedia_url': '-'},
#   {'name': 'post',
#    'type': 'WORK_OF_ART',
#    'salience': 0.00031139494967646897,
#    'wikipedia_url': '-'},
#   {'name': 'Team',
#    'type': 'ORGANIZATION',
#    'salience': 0.0003110952384304255,
#    'wikipedia_url': '-'},
#   {'name': 'Privacy Policy',
#    'type': 'WORK_OF_ART',
#    'salience': 0.00027324180700816214,
#    'wikipedia_url': '-'},
#   {'name': 'employer',
#    'type': 'PERSON',
#    'salience': 0.00027318557840771973,
#    'wikipedia_url': '-'},
#   {'name': 'countries',
#    'type': 'LOCATION',
#    'salience': 0.000273157813353464,
#    'wikipedia_url': '-'},
#   {'name': 'exec',
#    'type': 'PERSON',
#    'salience': 0.0002676220901776105,
#    'wikipedia_url': '-'},
#   {'name': 'docker exec example',
#    'type': 'PERSON',
#    'salience': 0.00026747980155050755,
#    'wikipedia_url': '-'},
#   {'name': 'docker exec',
#    'type': 'PERSON',
#    'salience': 0.0002673770650289953,
#    'wikipedia_url': '-'},
#   {'name': 'bin',
#    'type': 'PERSON',
#    'salience': 0.00025651350733824074,
#    'wikipedia_url': '-'},
#   {'name': 'bin',
#    'type': 'PERSON',
#    'salience': 0.00025618443032726645,
#    'wikipedia_url': '-'},
#   {'name': 'IMAGE',
#    'type': 'WORK_OF_ART',
#    'salience': 0.00024397044035140425,
#    'wikipedia_url': '-'},
#   {'name': 'Ben Cotton',
#    'type': 'PERSON',
#    'salience': 0.00023118723765946925,
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Ben_Cotton'},
#   {'name': 'UNIX',
#    'type': 'CONSUMER_GOOD',
#    'salience': 0.00023114965006243438,
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Unix'},
#   {'name': 'Slackware',
#    'type': 'CONSUMER_GOOD',
#    'salience': 0.00023113105271477252,
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Slackware'},
#   {'name': 'ClaraBDias',
#    'type': 'PERSON',
#    'salience': 0.00023103981220629066,
#    'wikipedia_url': '-'},
#   {'name': 'os-release',
#    'type': 'WORK_OF_ART',
#    'salience': 0.00019537851039785892,
#    'wikipedia_url': '-'},
#   {'name': 'release',
#    'type': 'WORK_OF_ART',
#    'salience': 0.00019537005573511124,
#    'wikipedia_url': '-'},
#   {'name': 'CentOS',
#    'type': 'CONSUMER_GOOD',
#    'salience': 0.000185337383300066,
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/CentOS'},
#   {'name': 'IRC',
#    'type': 'ORGANIZATION',
#    'salience': 0.00018381234258413315,
#    'wikipedia_url': '-'},
#   {'name': 'The EnterprisersProject.com',
#    'type': 'ORGANIZATION',
#    'salience': 0.00018376161460764706,
#    'wikipedia_url': '-'},
#   {'name': 'United States',
#    'type': 'LOCATION',
#    'salience': 0.00018373667262494564,
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/United_States'},
#   {'name': 'Denys P',
#    'type': 'PERSON',
#    'salience': 0.00018246598483528942,
#    'wikipedia_url': '-'},
#   {'name': 'boot dev home',
#    'type': 'LOCATION',
#    'salience': 0.00017164708697237074,
#    'wikipedia_url': '-'},
#   {'name': 'session',
#    'type': 'EVENT',
#    'salience': 0.0001715279940981418,
#    'wikipedia_url': '-'},
#   {'name': 'VERSION_ID',
#    'type': 'PERSON',
#    'salience': 0.00016903663345146924,
#    'wikipedia_url': '-'},
#   {'name': 'GIMP 2.10.',
#    'type': 'CONSUMER_GOOD',
#    'salience': 0.00016159942606464028,
#    'wikipedia_url': '-'},
#   {'name': 'Mira Edorra',
#    'type': 'ORGANIZATION',
#    'salience': 0.00016158109065145254,
#    'wikipedia_url': '-'},
#   {'name': 'RSS',
#    'type': 'ORGANIZATION',
#    'salience': 0.00016142326057888567,
#    'wikipedia_url': '-'},
#   {'name': 'Footer',
#    'type': 'PERSON',
#    'salience': 0.00016141765809152275,
#    'wikipedia_url': '-'},
#   {'name': 'CIO',
#    'type': 'ORGANIZATION',
#    'salience': 0.0001613843342056498,
#    'wikipedia_url': '-'},
#   {'name': 'ID_LIKE',
#    'type': 'PERSON',
#    'salience': 0.00014845869736745954,
#    'wikipedia_url': '-'},
#   {'name': 'VERSION',
#    'type': 'WORK_OF_ART',
#    'salience': 0.00011539967090357095,
#    'wikipedia_url': '-'},
#   {'name': '2015', 'type': 'DATE', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '2016', 'type': 'DATE', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '2017', 'type': 'DATE', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '2018', 'type': 'DATE', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '2019', 'type': 'DATE', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '20 Jun 2019',
#    'type': 'DATE',
#    'salience': 0.0,
#    'wikipedia_url': '-'},
#   {'name': '28 Jun 2019',
#    'type': 'DATE',
#    'salience': 0.0,
#    'wikipedia_url': '-'},
#   {'name': '28 Jun 2019',
#    'type': 'DATE',
#    'salience': 0.0,
#    'wikipedia_url': '-'},
#   {'name': '17 Jul 2019',
#    'type': 'DATE',
#    'salience': 0.0,
#    'wikipedia_url': '-'},
#   {'name': '30 Jul 2019',
#    'type': 'DATE',
#    'salience': 0.0,
#    'wikipedia_url': '-'},
#   {'name': '17 Sep 2019',
#    'type': 'DATE',
#    'salience': 0.0,
#    'wikipedia_url': '-'},
#   {'name': '17 Sep 2019',
#    'type': 'DATE',
#    'salience': 0.0,
#    'wikipedia_url': '-'},
#   {'name': '2020', 'type': 'DATE', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '5', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '2019', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '2017', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '7', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '1', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '1', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '2019', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '1', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '6', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '3', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '17', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '2019', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '28', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '3.7', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '678', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '2019', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '6', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '3', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '2019', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '20', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '7.6', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '2.10', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '3', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '2018', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '28', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '2019', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '7', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': 'one', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '6', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '2019', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '17', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '30', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '2020', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '6', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '2016', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '4', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '2015', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '2019', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '1', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '13', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '178', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '1', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '7', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '1', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '12', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '17', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '7', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'},
#   {'name': '1', 'type': 'NUMBER', 'salience': 0.0, 'wikipedia_url': '-'}],
#  'categories': [{'name': '/Computers & Electronics/Programming',
#    'confidence': 0.9399999976158142},
#   {'name': '/Science/Computer Science', 'confidence': 0.9100000262260437}]}
